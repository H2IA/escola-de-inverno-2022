# %% [markdown]
# <a href="https://colab.research.google.com/github/H2IA/escola-de-inverno-2022/blob/main/notebooks/Escola_de_Inverno_2022_PLN_Tarefa_Pr%C3%A1tica.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)
# # Escola de Inverno 2022
#
# ## Prática de PLN

# %% [markdown]
# ## Recursos Externos
#
# Você precisará baixar os seguintes recursos externos no seu ambiente de execução (sua máquina ou o colab).
#
# [OpLexicon](https://www.inf.pucrs.br/linatural/wordpress/recursos-e-ferramentas/oplexicon/)
#
# [Corpus](https://www.kaggle.com/code/leandrodoze/sentiment-analysis-in-portuguese/data?select=Tweets_Mg.csv)
